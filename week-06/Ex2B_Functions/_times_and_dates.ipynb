# %% [markdown]
# Lab 2 of Exercise 2.B, working with datetime functions

# %%
import datetime

# %% [markdown]
# # Today

# %%
Today = datetime.datetime.now()

# %%
print(Today.strftime("Today is %A, %B %d, %Y"))
# Out:
# Today is Tuesday, May 12, 2026

# %%
birthday = datetime.date(2002, 6, 15)

# %%
print(birthday.strftime("My birthday is %m/%d/%Y"))
# Out:
# My birthday is 06/15/2002

# %% [markdown]
# # Next 90 Days

# %%
ninety_d = Today + datetime.timedelta(days=90)

# %%
print(ninety_d.strftime("90 days from today is %B %d, %Y"))
# Out:
# 90 days from today is August 10, 2026

# %% [markdown]
# # Time for Dinner

# %%
dinner_time = datetime.time(19, 30)

# %%
print(dinner_time.strftime("Let's meet for dinner at %I:%M %p"))
# Out:
# Let's meet for dinner at 07:30 PM
